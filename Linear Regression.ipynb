# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv(
    "Datasets/Salary_dataset_linear_regression.csv"
)
data.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
X_train = np.array(data['YearsExperience'])
y_train = np.array(data['Salary'])
X_train = X_train / max(X_train)
y_train = y_train / max(y_train)

# %%
# X_train = data['YearsExperience'] 
# y_train = data['Salary']
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
w, b = 100, 10
m = X_train.shape[0]
m
# Out:
# 30

# %%
def costs(w, b, m, X_train, y_train):
    cost, var1, var2 = 0, 0, 0
    for i in range(m):
        z = w * X_train[i] + b
        cost += (z - y_train[i]) ** 2
        var1 += (z - y_train[i]) * X_train[i]
        var2 += (z - y_train[i])
    cost = 1 / 2 / m * cost
    var1 = 1 / m * var1
    var2 = 1 / m * var2
    return cost, var1, var2

# %%
def gradientDescent(w, b, m,  X_train, y_train):
    alpha = 0.01
    iterations = 50000
    wn = w
    bn = b
    for i in range(iterations):
        cost, var1, var2 = costs(
            wn, bn, m,  X_train, y_train
        )
        wn = wn - alpha * var1
        bn = bn - alpha * var2
        print(f"Iteration {i}: cost = {cost}")
    return wn, bn

# %%
wn, bn = gradientDescent(w, b, m,  X_train, y_train)
y_pred = wn * X_train + bn
# Out:
# Iteration 0: cost = 2167.783646603637
# Iteration 1: cost = 2117.321600565533
# Iteration 2: cost = 2068.1340306232737
# Iteration 3: cost = 2020.1886303950698
# Iteration 4: cost = 1973.4539125543522
# Iteration 5: cost = 1927.8991880643416
# Iteration 6: cost = 1883.4945459390785
# Iteration 7: cost = 1840.2108335175747
# Iteration 8: cost = 1798.019637238069
# Iteration 9: cost = 1756.8932638997132
# Iteration 10: cost = 1716.8047223993292
# Iteration 11: cost = 1677.727705931192
# Iteration 12: cost = 1639.6365746380989
# Iteration 13: cost = 1602.506338702287
# Iteration 14: cost = 1566.3126418650436
# Iteration 15: cost = 1531.0317453641444
# Iteration 16: cost = 1496.640512278522
# Iteration 17: cost = 1463.1163922698438
# Iteration 18: cost = 1430.4374067109363
# Iteration 19: cost = 1398.5821341912447
# Iteration 20: cost = 1367.5296963897742
# Iteration 21: cost = 1337.2597443061936
# Iteration 22: cost = 1307.7524448410156
# Iteration 23: cost = 1278.9884677160157
# ...

# %%
plt.plot(X_train, y_train)
plt.plot(X_train, y_pred, color='red')
plt.show()

# %%
X_train
# Out:
# 0      1.2
# 1      1.4
# 2      1.6
# 3      2.1
# 4      2.3
# 5      3.0
# 6      3.1
# 7      3.3
# 8      3.3
# 9      3.8
# 10     4.0
# 11     4.1
# 12     4.1
# 13     4.2
# 14     4.6
# 15     5.0
# 16     5.2
# 17     5.4
# 18     6.0
# 19     6.1
# 20     6.9
# 21     7.2
# 22     8.0
# 23     8.3
# 24     8.8
# 25     9.1
# 26     9.6
# 27     9.7
# 28    10.4
# 29    10.6
# Name: YearsExperience, dtype: float64
